# %%
import pandas as pd

# %%
df1=pd.read_csv('matches.csv')
df2=pd.read_csv('deliveries.csv')

# %%
df1
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
c=pd.DataFrame(df2.columns)
c
# Out:
#                    0
# 0           match_id
# 1             inning
# 2       batting_team
# 3       bowling_team
# 4               over
# 5               ball
# 6            batsman
# 7        non_striker
# 8             bowler
# 9      is_super_over
# 10         wide_runs
# 11          bye_runs
# 12       legbye_runs
# 13       noball_runs
# 14      penalty_runs
# 15      batsman_runs
# 16        extra_runs
# 17        total_runs
# 18  player_dismissed
# 19    dismissal_kind
# 20           fielder

# %%
print(df2.groupby(['batsman','bowler'])['batsman_runs'].sum().sort_values(ascending=False).head(10))
# Out:
# batsman     bowler
# SK Raina    PP Chawla          152
# V Kohli     A Mishra           149
#             UT Yadav           141
# RG Sharma   PP Chawla          136
# SK Raina    Harbhajan Singh    132
# KA Pollard  A Mishra           131
# V Kohli     DJ Bravo           130
#             R Ashwin           127
# DA Warner   P Kumar            124
# RG Sharma   M Morkel           119
# Name: batsman_runs, dtype: int64

# %%
out=df2[(df2['player_dismissed'].notna())&(df2['dismissal_kind']!='run out')&(df2['dismissal_kind']!='retired_hurt')&(df2['dismissal_kind']!='obstructing_the_field')]

# %%
out
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 116            1       1          Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150402       636       2  Royal Challengers Bangalore
# 150416       636       2  Royal Challengers Bangalore
# 150422       636       2  Royal Challengers Bangalore
# 150432       636       2  Royal Challengers Bangalore
# 150438       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball         batsman  \
# 11      Royal Challengers Bangalore     2     5       DA Warner
# 64      Royal Challengers Bangalore    11     3        S Dhawan
# 94      Royal Challengers Bangalore    16     2    MC Henriques
# ...

# %%
df2['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
out.groupby(['batsman', 'bowler'])['player_dismissed'].count()
# Out:
# batsman         bowler
# A Ashish Reddy  A Nehra          1
#                 BW Hilfenhaus    1
#                 DJ Bravo         1
#                 KA Pollard       1
#                 M Morkel         1
#                                 ..
# Z Khan          KH Pandya        1
#                 KV Sharma        1
#                 PP Chawla        1
#                 SC Ganguly       1
#                 SK Warne         1
# Name: player_dismissed, Length: 5494, dtype: int64

# %%
df2.groupby(['batsman','bowler'])['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman     bowler
# SK Raina    PP Chawla          152
# V Kohli     A Mishra           149
#             UT Yadav           141
# RG Sharma   PP Chawla          136
# SK Raina    Harbhajan Singh    132
# KA Pollard  A Mishra           131
# V Kohli     DJ Bravo           130
#             R Ashwin           127
# DA Warner   P Kumar            124
# RG Sharma   M Morkel           119
# Name: batsman_runs, dtype: int64

# %%
mask=df2['batsman_runs']==6
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459    False
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
df2[mask].groupby('batsman').size().sort_values(ascending=False).head(1)
# Out:
# batsman
# CH Gayle    266
# dtype: int64

# %%
df2[df2['batsman_runs']==4].groupby('batsman').size().sort_values(ascending=False).head(1)
# Out:
# batsman
# G Gambhir    484
# dtype: int64

# %%
df2.groupby('batting_team')['total_runs'].sum()
# Out:
# batting_team
# Chennai Super Kings            20899
# Deccan Chargers                11463
# Delhi Daredevils               21953
# Gujarat Lions                   4862
# Kings XI Punjab                23068
# Kochi Tuskers Kerala            1901
# Kolkata Knight Riders          21965
# Mumbai Indians                 24521
# Pune Warriors                   6358
# Rajasthan Royals               17703
# Rising Pune Supergiant          2470
# Rising Pune Supergiants         2063
# Royal Challengers Bangalore    23436
# Sunrisers Hyderabad            11652
# Name: total_runs, dtype: int64

# %%
df2.groupby('bowling_team')['total_runs'].sum()
# Out:
# bowling_team
# Chennai Super Kings            19790
# Deccan Chargers                11618
# Delhi Daredevils               22343
# Gujarat Lions                   5090
# Kings XI Punjab                23270
# Kochi Tuskers Kerala            1986
# Kolkata Knight Riders          22035
# Mumbai Indians                 23835
# Pune Warriors                   6857
# Rajasthan Royals               17854
# Rising Pune Supergiant          2436
# Rising Pune Supergiants         2113
# Royal Challengers Bangalore    23622
# Sunrisers Hyderabad            11465
# Name: total_runs, dtype: int64

# %%
death_overs=df2[df2['over'].isin([16,17,18,19,20])].value_counts()

# %%
runs_conceded = death_overs.groupby('bowler')['total_runs'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 runs_conceded = death_overs.groupby('bowler')['total_runs'].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: total_runs'

# %%
legal_balls=death_overs[(death_overs['wide_runs']==0)&(death_overs['noball_runs']==0)].groupby('bowler').size()

# %%
overs_bowled=legal_balls/6

# %%
df2.groupby('bowler')[economic_rate].sort_values(ascending=False).head(1)

# %%
df2.groupby('over')['total_runs'].sum().sort_values(ascending=False).head(1)

# %%
df2.groupby('over')['total_runs'].sum().sort_values(ascending=False).head(1)

# %%
df2['dismissal_kind'].unique()

# %%
wickets=df2[(df2['player_dismissed'].notna())&(df2['dismissal_kind']!='run out')&(df2['dismissal_kind']!='retired hurt')&(df2['dismissal_kind']!='obstructing the field')]

# %%
wickets

# %%
wickets.groupby('over')['dismissal_kind'].count().sort_values(ascending=False).head(1)

# %% [markdown]
# # Orange Cap Table

# %%
df2.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False)

# %% [markdown]
# # Purple Cap table

# %%
wickets=df2[(df2['player_dismissed'].notna())&(df2['dismissal_kind']!='run out')&(df2['dismissal_kind']!='retired hurt')&(df2['dismissal_kind']!='obstructing the field')]

# %%
wickets.groupby('bowler')['dismissal_kind'].count().sort_values(ascending=False)

# %% [markdown]
# # Top Partnership

# %%
df2.groupby(['batsman','non_striker'])['batsman_runs'].sum().sort_values(ascending=False).head(10)

# %%
mask1=df2[df2['over'].isin([1,2,3,4,5,6])]
mask1
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150370       636       2  Royal Challengers Bangalore
# 150371       636       2  Royal Challengers Bangalore
# 150372       636       2  Royal Challengers Bangalore
# 150373       636       2  Royal Challengers Bangalore
# 150374       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball    batsman non_striker  \
# 0       Royal Challengers Bangalore     1     1  DA Warner    S Dhawan
# 1       Royal Challengers Bangalore     1     2  DA Warner    S Dhawan
# 2       Royal Challengers Bangalore     1     3  DA Warner    S Dhawan
# ...

# %%
power_play_overs=mask.groupby('batting_team')['batsman_runs'].sum().sort_values(ascending=False)
power_play_overs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 power_play_overs=mask.groupby('batting_team')['batsman_runs'].sum().sort_values(ascending=False)
#       2 power_play_overs
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2259, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2256     raise TypeError("as_index=False only valid with DataFrame")
#    2257 axis = self._get_axis_number(axis)
# -> 2259 return SeriesGroupBy(
#    2260     obj=self,
#    2261     keys=by,
#    2262     axis=axis,
#    2263     level=level,
#    2264     as_index=as_index,
#    2265     sort=sort,
#    2266     group_keys=group_keys,
#    2267     observed=observed,
#    2268     dropna=dropna,
#    2269 )
#
# ...

# %%
mask2=df2[df2['over'].isin([7,8,9,10,11,12,13,14,15])]
mask2

# %%
middle_overs=mask.groupby('batting_team')['batsman_runs'].sum().sort_values(ascending=False)
middle_overs

# %%
mask3=df2[df2['over'].isin([16,17,18,19,20])]
mask3

# %%
death_overs=mask1.groupby('batting_team')['batsman_runs'].sum().sort_values(ascending=False)
death_overs
# Out:
# batting_team
# Kings XI Punjab                6428
# Mumbai Indians                 6393
# Royal Challengers Bangalore    6254
# Kolkata Knight Riders          6237
# Delhi Daredevils               6232
# Chennai Super Kings            5649
# Rajasthan Royals               4744
# Sunrisers Hyderabad            3278
# Deccan Chargers                3202
# Pune Warriors                  1776
# Gujarat Lions                  1482
# Rising Pune Supergiant          746
# Kochi Tuskers Kerala            613
# Rising Pune Supergiants         609
# Name: batsman_runs, dtype: int64

# %%
mask1.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(1)
# Out:
# batsman
# G Gambhir    2213
# Name: batsman_runs, dtype: int64

# %% [markdown]
# #### Average run scored in every over

# %%
df2.groupby('over')['total_runs'].mean()
# Out:
# over
# 1     0.955635
# 2     1.121601
# 3     1.242057
# 4     1.291698
# 5     1.298832
# 6     1.321933
# 7     1.074869
# 8     1.149635
# 9     1.189325
# 10    1.170981
# 11    1.233177
# 12    1.269347
# 13    1.275509
# 14    1.313694
# 15    1.373206
# 16    1.418031
# 17    1.495300
# 18    1.561685
# 19    1.600031
# 20    1.707736
# Name: total_runs, dtype: float64

# %% [markdown]
# ### which over produces the most sixes

# %%
mask=df2[df2['batsman_runs']==6]
mask
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150395       636       2  Royal Challengers Bangalore
# 150413       636       2  Royal Challengers Bangalore
# 150428       636       2  Royal Challengers Bangalore
# 150440       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball       batsman     non_striker  \
# 10      Royal Challengers Bangalore     2     4     DA Warner        S Dhawan
# 47      Royal Challengers Bangalore     8     4  MC Henriques        S Dhawan
# 75      Royal Challengers Bangalore    13     2  Yuvraj Singh    MC Henriques
# ...

# %%
mask.groupby('over')['batsman_runs'].size().sort_values(ascending=False).head(1)
# Out:
# over
# 18    523
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ## Visualisation

# %% [markdown]
# #### Top 10 batsmen

# %%
df2.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='batsman'>

# %% [markdown]
# ### Top 10 bowlers

# %%
wickets=df2[(df2['player_dismissed'].notna())&(df2['dismissal_kind']!='run out')&(df2['dismissal_kind']!='retired_hurt')&(df2['dismissal_kind']!='obstructing_the_field')]

# %%
wickets.groupby('bowler')['dismissal_kind'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='bowler'>

# %% [markdown]
# ### sixes by team

# %%
mask=df2[df2['batsman_runs']==6]
mask
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150395       636       2  Royal Challengers Bangalore
# 150413       636       2  Royal Challengers Bangalore
# 150428       636       2  Royal Challengers Bangalore
# 150440       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball       batsman     non_striker  \
# 10      Royal Challengers Bangalore     2     4     DA Warner        S Dhawan
# 47      Royal Challengers Bangalore     8     4  MC Henriques        S Dhawan
# 75      Royal Challengers Bangalore    13     2  Yuvraj Singh    MC Henriques
# ...

# %%
mask.groupby('batting_team')['batsman_runs'].size().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='batting_team'>

# %% [markdown]
# ### fours by team

# %%
mask=df2[df2['batsman_runs']==4]
mask.groupby('batting_team')['batsman_runs'].size().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='batting_team'>

# %% [markdown]
# ### runs by over

# %%
df2.groupby('over')['total_runs'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='over'>

# %% [markdown]
# ### wickets by over

# %%
wickets=df2[df2[(df2['player_dismissed'].notna())&(df2['dismissal_kind']!='run out')&(df2['dismissal_kind']!='retired_hurt')&(df2['dismissal_kind']!='obstructing_the_field')]]

# %%
wickets.groupby('bowler')['batsman_runs'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='bowler'>
